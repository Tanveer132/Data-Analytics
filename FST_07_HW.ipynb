# %% [markdown]
# **Study of series and panel and DataFrame in pandas**

# %%
#importing the pandas
import pandas as pd

# %% [markdown]
# **Series**

# %% [markdown]
# **DataFrame**

# %%
#creating the data to convert in to DF
data=[{"roll":1,"marks":45},{"roll":5,"marks":12,"res":"pass"}]
df=pd.DataFrame(data)
print(df)
# Out:
#            roll             marks   res
# 0  [1, 2, 3, 4]  [34, 45, 56, 67]   NaN
# 1             5                12  pass
